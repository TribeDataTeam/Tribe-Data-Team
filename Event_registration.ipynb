# %%
import numpy as np
import pandas as pd
import requests
import json

# %%
api_key = "eyJhbGciOiJIUzI1NiJ9.eyJ0aWQiOjUwMjA4MDk5NSwiYWFpIjoxMSwidWlkIjozMTY2NzY3MCwiaWFkIjoiMjAyNS0wNC0yMFQxMjoxNzo0MC40MDFaIiwicGVyIjoibWU6d3JpdGUiLCJhY3RpZCI6MTI2MjUwMzAsInJnbiI6InVzZTEifQ.EqePBq-dzRrAMUz8NzoLHe_7YIZWgBdHv1M-he6cb3U"
board_id = "5777591311"

headers = {"Authorization": api_key, "Content-Type": "application/json"}

# boards refers to the item we are trying to access, which in this case is a form created on monday
query = (
    """
query {
        boards(ids: %s) {
            items_page (limit: 100) {
                items{
                    id
                    name
                    column_values {
                        id
                        column{
                            id
                            title
                        }
                        text
                }
            }
        }
    }

}

"""
    % board_id
)

response = requests.post(
    url="https://api.monday.com/v2", json={"query": query}, headers=headers
)


if response.status_code == 200:
    data = response.json()
    print(json.dumps(data, indent=2))
else:
    print("Error:", response.status_code, response.text)


rows = []

for item in data["data"]["boards"][0]["items_page"]["items"]:
    row = {
        "id": item["id"],
        "name": item["name"],
    }
    for col in item["column_values"]:
        row[col["column"]["title"]] = col["text"]
    rows.append(row)
# Out:
# {
#   "data": {
#     "boards": [
#       {
#         "items_page": {
#           "items": [
#             {
#               "id": "5803472068",
#               "name": "Peixuan Liu",
#               "column_values": [
#                 {
#                   "id": "email",
#                   "column": {
#                     "id": "email",
#                     "title": "Contact Email"
#                   },
#                   "text": "lauprinsha@gmail.com"
#                 },
#                 {
#                   "id": "dropdown",
#                   "column": {
#                     "id": "dropdown",
#                     "title": "Food preferences"
#                   },
#                   "text": "No preferences"
#                 },
#                 {
#                   "id": "text5",
#                   "column": {
#                     "id": "text5",
#                     "title": "Please specify your food allergies"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "status06",
#                   "column": {
#                     "id": "status06",
#                     "title": "I consent to the storage and processing of my data in accordance with the privacy statement"
#                   },
#                   "text": "Yes"
#                 }
#               ]
#             },
#             {
#               "id": "5803520218",
#               "name": "Jos\u00e9 Pekkarinen",
#               "column_values": [
#                 {
#                   "id": "email",
#                   "column": {
#                     "id": "email",
#                     "title": "Contact Email"
#                   },
#                   "text": "jose.pekkarinen@foxhound.fi"
#                 },
#                 {
#                   "id": "dropdown",
#                   "column": {
#                     "id": "dropdown",
#                     "title": "Food preferences"
#                   },
#                   "text": "No preferences"
#                 },
#                 {
#                   "id": "text5",
#                   "column": {
#                     "id": "text5",
#                     "title": "Please specify your food allergies"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "status06",
#                   "column": {
#                     "id": "status06",
#                     "title": "I consent to the storage and processing of my data in accordance with the privacy statement"
#                   },
#                   "text": "Yes"
#                 }
#               ]
#             },
#             {
#               "id": "5814190285",
#               "name": "Tom Asbill",
#               "column_values": [
#                 {
#                   "id": "email",
#                   "column": {
#                     "id": "email",
#                     "title": "Contact Email"
#                   },
#                   "text": "jtom.asbill@gmail.com"
#                 },
#                 {
#                   "id": "dropdown",
#                   "column": {
#                     "id": "dropdown",
#                     "title": "Food preferences"
#                   },
#                   "text": "Gluten free"
#                 },
#                 {
#                   "id": "text5",
#                   "column": {
#                     "id": "text5",
#                     "title": "Please specify your food allergies"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "status06",
#                   "column": {
#                     "id": "status06",
#                     "title": "I consent to the storage and processing of my data in accordance with the privacy statement"
#                   },
#                   "text": "Yes"
#                 }
#               ]
#             },
#             {
#               "id": "5816832116",
#               "name": "Ivana Curcic",
#               "column_values": [
#                 {
#                   "id": "email",
#                   "column": {
#                     "id": "email",
#                     "title": "Contact Email"
#                   },
#                   "text": "ivana.curcic22@gmail.com"
#                 },
#                 {
#                   "id": "dropdown",
#                   "column": {
#                     "id": "dropdown",
#                     "title": "Food preferences"
#                   },
#                   "text": "Vegetarian"
#                 },
#                 {
#                   "id": "text5",
#                   "column": {
#                     "id": "text5",
#                     "title": "Please specify your food allergies"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "status06",
#                   "column": {
#                     "id": "status06",
#                     "title": "I consent to the storage and processing of my data in accordance with the privacy statement"
#                   },
#                   "text": "Yes"
#                 }
#               ]
#             },
#             {
#               "id": "5844888673",
#               "name": "Karoliina Rautavirta",
#               "column_values": [
#                 {
#                   "id": "email",
#                   "column": {
#                     "id": "email",
#                     "title": "Contact Email"
#                   },
#                   "text": "karoliina.rautavirta@gmail.com"
#                 },
#                 {
#                   "id": "dropdown",
#                   "column": {
#                     "id": "dropdown",
#                     "title": "Food preferences"
#                   },
#                   "text": "No preferences"
#                 },
#                 {
#                   "id": "text5",
#                   "column": {
#                     "id": "text5",
#                     "title": "Please specify your food allergies"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "status06",
#                   "column": {
#                     "id": "status06",
#                     "title": "I consent to the storage and processing of my data in accordance with the privacy statement"
#                   },
#                   "text": "Yes"
#                 }
#               ]
#             },
#             {
#               "id": "5845246269",
#               "name": "Madhuri",
#               "column_values": [
#                 {
#                   "id": "email",
#                   "column": {
#                     "id": "email",
#                     "title": "Contact Email"
#                   },
#                   "text": "venkata.dhurjati@tuni.fi"
#                 },
#                 {
#                   "id": "dropdown",
#                   "column": {
#                     "id": "dropdown",
#                     "title": "Food preferences"
#                   },
#                   "text": "Vegetarian, Gluten free"
#                 },
#                 {
#                   "id": "text5",
#                   "column": {
#                     "id": "text5",
#                     "title": "Please specify your food allergies"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "status06",
#                   "column": {
#                     "id": "status06",
#                     "title": "I consent to the storage and processing of my data in accordance with the privacy statement"
#                   },
#                   "text": "Yes"
#                 }
#               ]
#             },
#             {
#               "id": "5846173690",
#               "name": "DIPANJAN DAS",
#               "column_values": [
#                 {
#                   "id": "email",
#                   "column": {
#                     "id": "email",
#                     "title": "Contact Email"
#                   },
#                   "text": "dip@xchi.space"
#                 },
#                 {
#                   "id": "dropdown",
#                   "column": {
#                     "id": "dropdown",
#                     "title": "Food preferences"
#                   },
#                   "text": "No preferences"
#                 },
#                 {
#                   "id": "text5",
#                   "column": {
#                     "id": "text5",
#                     "title": "Please specify your food allergies"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "status06",
#                   "column": {
#                     "id": "status06",
#                     "title": "I consent to the storage and processing of my data in accordance with the privacy statement"
#                   },
#                   "text": "Yes"
#                 }
#               ]
#             },
#             {
#               "id": "5851588990",
#               "name": "Randilu Soysa",
#               "column_values": [
#                 {
#                   "id": "email",
#                   "column": {
#                     "id": "email",
#                     "title": "Contact Email"
#                   },
#                   "text": "randilu.soysa@gmail.com"
#                 },
#                 {
#                   "id": "dropdown",
#                   "column": {
#                     "id": "dropdown",
#                     "title": "Food preferences"
#                   },
#                   "text": "No preferences"
#                 },
#                 {
#                   "id": "text5",
#                   "column": {
#                     "id": "text5",
#                     "title": "Please specify your food allergies"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "status06",
#                   "column": {
#                     "id": "status06",
#                     "title": "I consent to the storage and processing of my data in accordance with the privacy statement"
#                   },
#                   "text": "Yes"
#                 }
#               ]
#             },
#             {
#               "id": "5865416742",
#               "name": "Pavel Marek",
#               "column_values": [
#                 {
#                   "id": "email",
#                   "column": {
#                     "id": "email",
#                     "title": "Contact Email"
#                   },
#                   "text": "pavel.marek@bamomas.com"
#                 },
#                 {
#                   "id": "dropdown",
#                   "column": {
#                     "id": "dropdown",
#                     "title": "Food preferences"
#                   },
#                   "text": "No preferences"
#                 },
#                 {
#                   "id": "text5",
#                   "column": {
#                     "id": "text5",
#                     "title": "Please specify your food allergies"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "status06",
#                   "column": {
#                     "id": "status06",
#                     "title": "I consent to the storage and processing of my data in accordance with the privacy statement"
#                   },
#                   "text": "Yes"
#                 }
#               ]
#             },
#             {
#               "id": "5872917517",
#               "name": "Ahmed Mahdi",
#               "column_values": [
#                 {
#                   "id": "email",
#                   "column": {
#                     "id": "email",
#                     "title": "Contact Email"
#                   },
#                   "text": "am.ahmedmahdi@gmail.com"
#                 },
#                 {
#                   "id": "dropdown",
#                   "column": {
#                     "id": "dropdown",
#                     "title": "Food preferences"
#                   },
#                   "text": "No preferences"
#                 },
#                 {
#                   "id": "text5",
#                   "column": {
#                     "id": "text5",
#                     "title": "Please specify your food allergies"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "status06",
#                   "column": {
#                     "id": "status06",
#                     "title": "I consent to the storage and processing of my data in accordance with the privacy statement"
#                   },
#                   "text": "Yes"
#                 }
#               ]
#             },
#             {
#               "id": "5873190066",
#               "name": "Jyri",
#               "column_values": [
#                 {
#                   "id": "email",
#                   "column": {
#                     "id": "email",
#                     "title": "Contact Email"
#                   },
#                   "text": "filippov@lawyer.com"
#                 },
#                 {
#                   "id": "dropdown",
#                   "column": {
#                     "id": "dropdown",
#                     "title": "Food preferences"
#                   },
#                   "text": "No preferences"
#                 },
#                 {
#                   "id": "text5",
#                   "column": {
#                     "id": "text5",
#                     "title": "Please specify your food allergies"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "status06",
#                   "column": {
#                     "id": "status06",
#                     "title": "I consent to the storage and processing of my data in accordance with the privacy statement"
#                   },
#                   "text": "Yes"
#                 }
#               ]
#             },
#             {
#               "id": "5873708039",
#               "name": "Mikko Malmivaara",
#               "column_values": [
#                 {
#                   "id": "email",
#                   "column": {
#                     "id": "email",
#                     "title": "Contact Email"
#                   },
#                   "text": "mikko@electrodynamics.fi"
#                 },
#                 {
#                   "id": "dropdown",
#                   "column": {
#                     "id": "dropdown",
#                     "title": "Food preferences"
#                   },
#                   "text": "No preferences"
#                 },
#                 {
#                   "id": "text5",
#                   "column": {
#                     "id": "text5",
#                     "title": "Please specify your food allergies"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "status06",
#                   "column": {
#                     "id": "status06",
#                     "title": "I consent to the storage and processing of my data in accordance with the privacy statement"
#                   },
#                   "text": "Yes"
#                 }
#               ]
#             },
#             {
#               "id": "5874589413",
#               "name": "Ilari Huitti",
#               "column_values": [
#                 {
#                   "id": "email",
#                   "column": {
#                     "id": "email",
#                     "title": "Contact Email"
#                   },
#                   "text": "ilari.huitti@gmail.com"
#                 },
#                 {
#                   "id": "dropdown",
#                   "column": {
#                     "id": "dropdown",
#                     "title": "Food preferences"
#                   },
#                   "text": "No preferences"
#                 },
#                 {
#                   "id": "text5",
#                   "column": {
#                     "id": "text5",
#                     "title": "Please specify your food allergies"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "status06",
#                   "column": {
#                     "id": "status06",
#                     "title": "I consent to the storage and processing of my data in accordance with the privacy statement"
#                   },
#                   "text": "Yes"
#                 }
#               ]
#             },
#             {
#               "id": "5875341660",
#               "name": "Mate Mulato",
#               "column_values": [
#                 {
#                   "id": "email",
#                   "column": {
#                     "id": "email",
#                     "title": "Contact Email"
#                   },
#                   "text": "m.vortex45@gmail.com"
#                 },
#                 {
#                   "id": "dropdown",
#                   "column": {
#                     "id": "dropdown",
#                     "title": "Food preferences"
#                   },
#                   "text": "Vegetarian, Allergies"
#                 },
#                 {
#                   "id": "text5",
#                   "column": {
#                     "id": "text5",
#                     "title": "Please specify your food allergies"
#                   },
#                   "text": "Milk and grains"
#                 },
#                 {
#                   "id": "status06",
#                   "column": {
#                     "id": "status06",
#                     "title": "I consent to the storage and processing of my data in accordance with the privacy statement"
#                   },
#                   "text": "Yes"
#                 }
#               ]
#             },
#             {
#               "id": "5876509665",
#               "name": "Phuoc Trinh",
#               "column_values": [
#                 {
#                   "id": "email",
#                   "column": {
#                     "id": "email",
#                     "title": "Contact Email"
#                   },
#                   "text": "phuoc@xchi.space"
#                 },
#                 {
#                   "id": "dropdown",
#                   "column": {
#                     "id": "dropdown",
#                     "title": "Food preferences"
#                   },
#                   "text": "No preferences"
#                 },
#                 {
#                   "id": "text5",
#                   "column": {
#                     "id": "text5",
#                     "title": "Please specify your food allergies"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "status06",
#                   "column": {
#                     "id": "status06",
#                     "title": "I consent to the storage and processing of my data in accordance with the privacy statement"
#                   },
#                   "text": "Yes"
#                 }
#               ]
#             },
#             {
#               "id": "5876955226",
#               "name": "Reyver",
#               "column_values": [
#                 {
#                   "id": "email",
#                   "column": {
#                     "id": "email",
#                     "title": "Contact Email"
#                   },
#                   "text": "reyver.arley@gmail.com"
#                 },
#                 {
#                   "id": "dropdown",
#                   "column": {
#                     "id": "dropdown",
#                     "title": "Food preferences"
#                   },
#                   "text": "No preferences"
#                 },
#                 {
#                   "id": "text5",
#                   "column": {
#                     "id": "text5",
#                     "title": "Please specify your food allergies"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "status06",
#                   "column": {
#                     "id": "status06",
#                     "title": "I consent to the storage and processing of my data in accordance with the privacy statement"
#                   },
#                   "text": "Yes"
#                 }
#               ]
#             },
#             {
#               "id": "5877067691",
#               "name": "Avinash",
#               "column_values": [
#                 {
#                   "id": "email",
#                   "column": {
#                     "id": "email",
#                     "title": "Contact Email"
#                   },
#                   "text": "avinash.kodmurgi@gmail.com"
#                 },
#                 {
#                   "id": "dropdown",
#                   "column": {
#                     "id": "dropdown",
#                     "title": "Food preferences"
#                   },
#                   "text": "Vegetarian"
#                 },
#                 {
#                   "id": "text5",
#                   "column": {
#                     "id": "text5",
#                     "title": "Please specify your food allergies"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "status06",
#                   "column": {
#                     "id": "status06",
#                     "title": "I consent to the storage and processing of my data in accordance with the privacy statement"
#                   },
#                   "text": "Yes"
#                 }
#               ]
#             }
#           ]
#         }
#       }
#     ]
#   },
#   "extensions": {
#     "request_id": "280af57a-a741-9788-8204-a0df8bd9795b"
#   }
# }

# %%
reg_data = pd.DataFrame(rows)

reg_data
# Out:
#             id                  name                   Contact Email  \
# 0   5803472068           Peixuan Liu            lauprinsha@gmail.com
# 1   5803520218       José Pekkarinen     jose.pekkarinen@foxhound.fi
# 2   5814190285            Tom Asbill           jtom.asbill@gmail.com
# 3   5816832116          Ivana Curcic        ivana.curcic22@gmail.com
# 4   5844888673  Karoliina Rautavirta  karoliina.rautavirta@gmail.com
# 5   5845246269               Madhuri        venkata.dhurjati@tuni.fi
# 6   5846173690          DIPANJAN DAS                  dip@xchi.space
# 7   5851588990         Randilu Soysa         randilu.soysa@gmail.com
# 8   5865416742           Pavel Marek         pavel.marek@bamomas.com
# 9   5872917517           Ahmed Mahdi         am.ahmedmahdi@gmail.com
# 10  5873190066                  Jyri             filippov@lawyer.com
# 11  5873708039      Mikko Malmivaara        mikko@electrodynamics.fi
# 12  5874589413          Ilari Huitti          ilari.huitti@gmail.com
# 13  5875341660           Mate Mulato            m.vortex45@gmail.com
# 14  5876509665           Phuoc Trinh                phuoc@xchi.space
# 15  5876955226                Reyver          reyver.arley@gmail.com
# 16  5877067691               Avinash      avinash.kodmurgi@gmail.com
#
#            Food preferences Please specify your food allergies  \
# 0            No preferences
# 1            No preferences
# 2               Gluten free
# 3                Vegetarian
# 4            No preferences
# 5   Vegetarian, Gluten free
# 6            No preferences
# 7            No preferences
# 8            No preferences
# 9            No preferences
# 10           No preferences
# 11           No preferences
# 12           No preferences
# 13    Vegetarian, Allergies                    Milk and grains
# 14           No preferences
# 15           No preferences
# 16               Vegetarian
#
#    I consent to the storage and processing of my data in accordance with the privacy statement
# 0                                                 Yes
# 1                                                 Yes
# 2                                                 Yes
# 3                                                 Yes
# 4                                                 Yes
# 5                                                 Yes
# 6                                                 Yes
# 7                                                 Yes
# 8                                                 Yes
# 9                                                 Yes
# 10                                                Yes
# 11                                                Yes
# 12                                                Yes
# 13                                                Yes
# 14                                                Yes
# 15                                                Yes
# 16                                                Yes
