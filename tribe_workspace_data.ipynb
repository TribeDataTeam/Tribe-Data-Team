# %%
import numpy as np
import pandas as pd
import requests
import json

# %%
api_key = "eyJhbGciOiJIUzI1NiJ9.eyJ0aWQiOjUwMjA4MDk5NSwiYWFpIjoxMSwidWlkIjozMTY2NzY3MCwiaWFkIjoiMjAyNS0wNC0yMFQxMjoxNzo0MC40MDFaIiwicGVyIjoibWU6d3JpdGUiLCJhY3RpZCI6MTI2MjUwMzAsInJnbiI6InVzZTEifQ.EqePBq-dzRrAMUz8NzoLHe_7YIZWgBdHv1M-he6cb3U"
board_id = "6703549445"

headers = {"Authorization": api_key, "Content-Type": "application/json"}

# boards refers to the item we are trying to access, which in this case is a form created on monday
query = (
    """
query {
        boards(ids: %s) { 
            items_page (limit: 100) {
                items{
                    id
                    name
                    column_values {
                        id
                        column{
                            id
                            title
                        }
                        text
                }
            }
        }
    }
        
}

"""
    % board_id
)

response = requests.post(
    url="https://api.monday.com/v2", json={"query": query}, headers=headers
)


if response.status_code == 200:
    data = response.json()
    print(json.dumps(data, indent=2))
else:
    print("Error:", response.status_code, response.text)


rows = []

for item in data["data"]["boards"][0]["items_page"]["items"]:
    row = {
        "id": item["id"],
        "name": item["name"],
    }
    for col in item["column_values"]:
        row[col["column"]["title"]] = col["text"]
    rows.append(row)
# Out:
# {
#   "data": {
#     "boards": [
#       {
#         "items_page": {
#           "items": [
#             {
#               "id": "6765358368",
#               "name": "Incoming form answer",
#               "column_values": [
#                 {
#                   "id": "date__1",
#                   "column": {
#                     "id": "date__1",
#                     "title": "Visit date?"
#                   },
#                   "text": "2024-06-04"
#                 },
#                 {
#                   "id": "single_select__1",
#                   "column": {
#                     "id": "single_select__1",
#                     "title": "Have you visited the Tribe workspace before?"
#                   },
#                   "text": "Yes"
#                 },
#                 {
#                   "id": "single_select1__1",
#                   "column": {
#                     "id": "single_select1__1",
#                     "title": "How would you rate the overall comfort and atmosphere of the Tribe workspace?"
#                   },
#                   "text": "Excellent"
#                 },
#                 {
#                   "id": "multi_select__1",
#                   "column": {
#                     "id": "multi_select__1",
#                     "title": "Which of the following amenities do you find most valuable in the Tribe workspace? (Select all that apply)"
#                   },
#                   "text": "Collaboration spaces, Refreshment options (e.g., coffee, snacks)"
#                 },
#                 {
#                   "id": "single_select6__1",
#                   "column": {
#                     "id": "single_select6__1",
#                     "title": "How accessible do you find the Tribe workspace in terms of location and transportation options?"
#                   },
#                   "text": "Very accessible"
#                 },
#                 {
#                   "id": "single_select66__1",
#                   "column": {
#                     "id": "single_select66__1",
#                     "title": "How would you describe the sense of the community within the Tribe workspace?"
#                   },
#                   "text": "Strong and supportive"
#                 },
#                 {
#                   "id": "long_text__1",
#                   "column": {
#                     "id": "long_text__1",
#                     "title": "What improvements or additions would you like to see in the Tribe workspace to enhance your experience?"
#                   },
#                   "text": "Air conditioning (more fans etc.).\nCheck that there's milk for coffee. :D<3"
#                 }
#               ]
#             },
#             {
#               "id": "6765364436",
#               "name": "Incoming form answer",
#               "column_values": [
#                 {
#                   "id": "date__1",
#                   "column": {
#                     "id": "date__1",
#                     "title": "Visit date?"
#                   },
#                   "text": "2024-06-04"
#                 },
#                 {
#                   "id": "single_select__1",
#                   "column": {
#                     "id": "single_select__1",
#                     "title": "Have you visited the Tribe workspace before?"
#                   },
#                   "text": "Yes"
#                 },
#                 {
#                   "id": "single_select1__1",
#                   "column": {
#                     "id": "single_select1__1",
#                     "title": "How would you rate the overall comfort and atmosphere of the Tribe workspace?"
#                   },
#                   "text": "Excellent"
#                 },
#                 {
#                   "id": "multi_select__1",
#                   "column": {
#                     "id": "multi_select__1",
#                     "title": "Which of the following amenities do you find most valuable in the Tribe workspace? (Select all that apply)"
#                   },
#                   "text": "Refreshment options (e.g., coffee, snacks), Printing and scanning facilities, Collaboration spaces"
#                 },
#                 {
#                   "id": "single_select6__1",
#                   "column": {
#                     "id": "single_select6__1",
#                     "title": "How accessible do you find the Tribe workspace in terms of location and transportation options?"
#                   },
#                   "text": "Very accessible"
#                 },
#                 {
#                   "id": "single_select66__1",
#                   "column": {
#                     "id": "single_select66__1",
#                     "title": "How would you describe the sense of the community within the Tribe workspace?"
#                   },
#                   "text": "Strong and supportive"
#                 },
#                 {
#                   "id": "long_text__1",
#                   "column": {
#                     "id": "long_text__1",
#                     "title": "What improvements or additions would you like to see in the Tribe workspace to enhance your experience?"
#                   },
#                   "text": "Internet speed is only my negative feedback but overall everything is perfect "
#                 }
#               ]
#             },
#             {
#               "id": "6765853286",
#               "name": "Incoming form answer",
#               "column_values": [
#                 {
#                   "id": "date__1",
#                   "column": {
#                     "id": "date__1",
#                     "title": "Visit date?"
#                   },
#                   "text": "2024-06-04"
#                 },
#                 {
#                   "id": "single_select__1",
#                   "column": {
#                     "id": "single_select__1",
#                     "title": "Have you visited the Tribe workspace before?"
#                   },
#                   "text": "Yes"
#                 },
#                 {
#                   "id": "single_select1__1",
#                   "column": {
#                     "id": "single_select1__1",
#                     "title": "How would you rate the overall comfort and atmosphere of the Tribe workspace?"
#                   },
#                   "text": "Excellent"
#                 },
#                 {
#                   "id": "multi_select__1",
#                   "column": {
#                     "id": "multi_select__1",
#                     "title": "Which of the following amenities do you find most valuable in the Tribe workspace? (Select all that apply)"
#                   },
#                   "text": "High-speed internet"
#                 },
#                 {
#                   "id": "single_select6__1",
#                   "column": {
#                     "id": "single_select6__1",
#                     "title": "How accessible do you find the Tribe workspace in terms of location and transportation options?"
#                   },
#                   "text": "Very accessible"
#                 },
#                 {
#                   "id": "single_select66__1",
#                   "column": {
#                     "id": "single_select66__1",
#                     "title": "How would you describe the sense of the community within the Tribe workspace?"
#                   },
#                   "text": "Strong and supportive"
#                 },
#                 {
#                   "id": "long_text__1",
#                   "column": {
#                     "id": "long_text__1",
#                     "title": "What improvements or additions would you like to see in the Tribe workspace to enhance your experience?"
#                   },
#                   "text": "Maybe more small meeting rooms?"
#                 }
#               ]
#             },
#             {
#               "id": "6766178199",
#               "name": "Incoming form answer",
#               "column_values": [
#                 {
#                   "id": "date__1",
#                   "column": {
#                     "id": "date__1",
#                     "title": "Visit date?"
#                   },
#                   "text": "2024-06-04"
#                 },
#                 {
#                   "id": "single_select__1",
#                   "column": {
#                     "id": "single_select__1",
#                     "title": "Have you visited the Tribe workspace before?"
#                   },
#                   "text": "Yes"
#                 },
#                 {
#                   "id": "single_select1__1",
#                   "column": {
#                     "id": "single_select1__1",
#                     "title": "How would you rate the overall comfort and atmosphere of the Tribe workspace?"
#                   },
#                   "text": "Excellent"
#                 },
#                 {
#                   "id": "multi_select__1",
#                   "column": {
#                     "id": "multi_select__1",
#                     "title": "Which of the following amenities do you find most valuable in the Tribe workspace? (Select all that apply)"
#                   },
#                   "text": "Collaboration spaces"
#                 },
#                 {
#                   "id": "single_select6__1",
#                   "column": {
#                     "id": "single_select6__1",
#                     "title": "How accessible do you find the Tribe workspace in terms of location and transportation options?"
#                   },
#                   "text": "Very accessible"
#                 },
#                 {
#                   "id": "single_select66__1",
#                   "column": {
#                     "id": "single_select66__1",
#                     "title": "How would you describe the sense of the community within the Tribe workspace?"
#                   },
#                   "text": "Strong and supportive"
#                 },
#                 {
#                   "id": "long_text__1",
#                   "column": {
#                     "id": "long_text__1",
#                     "title": "What improvements or additions would you like to see in the Tribe workspace to enhance your experience?"
#                   },
#                   "text": ""
#                 }
#               ]
#             },
#             {
#               "id": "8995951295",
#               "name": "Incoming form answer",
#               "column_values": [
#                 {
#                   "id": "date__1",
#                   "column": {
#                     "id": "date__1",
#                     "title": "Visit date?"
#                   },
#                   "text": "2025-04-24"
#                 },
#                 {
#                   "id": "single_select__1",
#                   "column": {
#                     "id": "single_select__1",
#                     "title": "Have you visited the Tribe workspace before?"
#                   },
#                   "text": "No"
#                 },
#                 {
#                   "id": "single_select1__1",
#                   "column": {
#                     "id": "single_select1__1",
#                     "title": "How would you rate the overall comfort and atmosphere of the Tribe workspace?"
#                   },
#                   "text": "Excellent"
#                 },
#                 {
#                   "id": "multi_select__1",
#                   "column": {
#                     "id": "multi_select__1",
#                     "title": "Which of the following amenities do you find most valuable in the Tribe workspace? (Select all that apply)"
#                   },
#                   "text": "High-speed internet, Quiet work areas, Collaboration spaces, Refreshment options (e.g., coffee, snacks), Printing and scanning facilities"
#                 },
#                 {
#                   "id": "single_select6__1",
#                   "column": {
#                     "id": "single_select6__1",
#                     "title": "How accessible do you find the Tribe workspace in terms of location and transportation options?"
#                   },
#                   "text": "Very accessible"
#                 },
#                 {
#                   "id": "single_select66__1",
#                   "column": {
#                     "id": "single_select66__1",
#                     "title": "How would you describe the sense of the community within the Tribe workspace?"
#                   },
#                   "text": "Strong and supportive"
#                 },
#                 {
#                   "id": "long_text__1",
#                   "column": {
#                     "id": "long_text__1",
#                     "title": "What improvements or additions would you like to see in the Tribe workspace to enhance your experience?"
#                   },
#                   "text": ""
#                 }
#               ]
#             },
#             {
#               "id": "8995951868",
#               "name": "Incoming form answer",
#               "column_values": [
#                 {
#                   "id": "date__1",
#                   "column": {
#                     "id": "date__1",
#                     "title": "Visit date?"
#                   },
#                   "text": "2025-04-24"
#                 },
#                 {
#                   "id": "single_select__1",
#                   "column": {
#                     "id": "single_select__1",
#                     "title": "Have you visited the Tribe workspace before?"
#                   },
#                   "text": "No"
#                 },
#                 {
#                   "id": "single_select1__1",
#                   "column": {
#                     "id": "single_select1__1",
#                     "title": "How would you rate the overall comfort and atmosphere of the Tribe workspace?"
#                   },
#                   "text": "Good"
#                 },
#                 {
#                   "id": "multi_select__1",
#                   "column": {
#                     "id": "multi_select__1",
#                     "title": "Which of the following amenities do you find most valuable in the Tribe workspace? (Select all that apply)"
#                   },
#                   "text": "Collaboration spaces"
#                 },
#                 {
#                   "id": "single_select6__1",
#                   "column": {
#                     "id": "single_select6__1",
#                     "title": "How accessible do you find the Tribe workspace in terms of location and transportation options?"
#                   },
#                   "text": "Somewhat accessible"
#                 },
#                 {
#                   "id": "single_select66__1",
#                   "column": {
#                     "id": "single_select66__1",
#                     "title": "How would you describe the sense of the community within the Tribe workspace?"
#                   },
#                   "text": "Moderate and welcoming"
#                 },
#                 {
#                   "id": "long_text__1",
#                   "column": {
#                     "id": "long_text__1",
#                     "title": "What improvements or additions would you like to see in the Tribe workspace to enhance your experience?"
#                   },
#                   "text": ""
#                 }
#               ]
#             },
#             {
#               "id": "8995955041",
#               "name": "Incoming form answer",
#               "column_values": [
#                 {
#                   "id": "date__1",
#                   "column": {
#                     "id": "date__1",
#                     "title": "Visit date?"
#                   },
#                   "text": "2025-04-24"
#                 },
#                 {
#                   "id": "single_select__1",
#                   "column": {
#                     "id": "single_select__1",
#                     "title": "Have you visited the Tribe workspace before?"
#                   },
#                   "text": "No"
#                 },
#                 {
#                   "id": "single_select1__1",
#                   "column": {
#                     "id": "single_select1__1",
#                     "title": "How would you rate the overall comfort and atmosphere of the Tribe workspace?"
#                   },
#                   "text": "Excellent"
#                 },
#                 {
#                   "id": "multi_select__1",
#                   "column": {
#                     "id": "multi_select__1",
#                     "title": "Which of the following amenities do you find most valuable in the Tribe workspace? (Select all that apply)"
#                   },
#                   "text": "High-speed internet, Refreshment options (e.g., coffee, snacks)"
#                 },
#                 {
#                   "id": "single_select6__1",
#                   "column": {
#                     "id": "single_select6__1",
#                     "title": "How accessible do you find the Tribe workspace in terms of location and transportation options?"
#                   },
#                   "text": "Somewhat accessible"
#                 },
#                 {
#                   "id": "single_select66__1",
#                   "column": {
#                     "id": "single_select66__1",
#                     "title": "How would you describe the sense of the community within the Tribe workspace?"
#                   },
#                   "text": "Moderate and welcoming"
#                 },
#                 {
#                   "id": "long_text__1",
#                   "column": {
#                     "id": "long_text__1",
#                     "title": "What improvements or additions would you like to see in the Tribe workspace to enhance your experience?"
#                   },
#                   "text": ""
#                 }
#               ]
#             },
#             {
#               "id": "8995956945",
#               "name": "Incoming form answer",
#               "column_values": [
#                 {
#                   "id": "date__1",
#                   "column": {
#                     "id": "date__1",
#                     "title": "Visit date?"
#                   },
#                   "text": "2025-04-24"
#                 },
#                 {
#                   "id": "single_select__1",
#                   "column": {
#                     "id": "single_select__1",
#                     "title": "Have you visited the Tribe workspace before?"
#                   },
#                   "text": "No"
#                 },
#                 {
#                   "id": "single_select1__1",
#                   "column": {
#                     "id": "single_select1__1",
#                     "title": "How would you rate the overall comfort and atmosphere of the Tribe workspace?"
#                   },
#                   "text": "Good"
#                 },
#                 {
#                   "id": "multi_select__1",
#                   "column": {
#                     "id": "multi_select__1",
#                     "title": "Which of the following amenities do you find most valuable in the Tribe workspace? (Select all that apply)"
#                   },
#                   "text": "Quiet work areas"
#                 },
#                 {
#                   "id": "single_select6__1",
#                   "column": {
#                     "id": "single_select6__1",
#                     "title": "How accessible do you find the Tribe workspace in terms of location and transportation options?"
#                   },
#                   "text": "Very accessible"
#                 },
#                 {
#                   "id": "single_select66__1",
#                   "column": {
#                     "id": "single_select66__1",
#                     "title": "How would you describe the sense of the community within the Tribe workspace?"
#                   },
#                   "text": "Strong and supportive"
#                 },
#                 {
#                   "id": "long_text__1",
#                   "column": {
#                     "id": "long_text__1",
#                     "title": "What improvements or additions would you like to see in the Tribe workspace to enhance your experience?"
#                   },
#                   "text": ""
#                 }
#               ]
#             },
#             {
#               "id": "8995957691",
#               "name": "Incoming form answer",
#               "column_values": [
#                 {
#                   "id": "date__1",
#                   "column": {
#                     "id": "date__1",
#                     "title": "Visit date?"
#                   },
#                   "text": "2025-04-24"
#                 },
#                 {
#                   "id": "single_select__1",
#                   "column": {
#                     "id": "single_select__1",
#                     "title": "Have you visited the Tribe workspace before?"
#                   },
#                   "text": "No"
#                 },
#                 {
#                   "id": "single_select1__1",
#                   "column": {
#                     "id": "single_select1__1",
#                     "title": "How would you rate the overall comfort and atmosphere of the Tribe workspace?"
#                   },
#                   "text": "Good"
#                 },
#                 {
#                   "id": "multi_select__1",
#                   "column": {
#                     "id": "multi_select__1",
#                     "title": "Which of the following amenities do you find most valuable in the Tribe workspace? (Select all that apply)"
#                   },
#                   "text": "Collaboration spaces"
#                 },
#                 {
#                   "id": "single_select6__1",
#                   "column": {
#                     "id": "single_select6__1",
#                     "title": "How accessible do you find the Tribe workspace in terms of location and transportation options?"
#                   },
#                   "text": "Very accessible"
#                 },
#                 {
#                   "id": "single_select66__1",
#                   "column": {
#                     "id": "single_select66__1",
#                     "title": "How would you describe the sense of the community within the Tribe workspace?"
#                   },
#                   "text": "Strong and supportive"
#                 },
#                 {
#                   "id": "long_text__1",
#                   "column": {
#                     "id": "long_text__1",
#                     "title": "What improvements or additions would you like to see in the Tribe workspace to enhance your experience?"
#                   },
#                   "text": ""
#                 }
#               ]
#             },
#             {
#               "id": "8995960412",
#               "name": "Incoming form answer",
#               "column_values": [
#                 {
#                   "id": "date__1",
#                   "column": {
#                     "id": "date__1",
#                     "title": "Visit date?"
#                   },
#                   "text": "2025-04-24"
#                 },
#                 {
#                   "id": "single_select__1",
#                   "column": {
#                     "id": "single_select__1",
#                     "title": "Have you visited the Tribe workspace before?"
#                   },
#                   "text": "No"
#                 },
#                 {
#                   "id": "single_select1__1",
#                   "column": {
#                     "id": "single_select1__1",
#                     "title": "How would you rate the overall comfort and atmosphere of the Tribe workspace?"
#                   },
#                   "text": "Excellent"
#                 },
#                 {
#                   "id": "multi_select__1",
#                   "column": {
#                     "id": "multi_select__1",
#                     "title": "Which of the following amenities do you find most valuable in the Tribe workspace? (Select all that apply)"
#                   },
#                   "text": "Other (please specify), Collaboration spaces"
#                 },
#                 {
#                   "id": "single_select6__1",
#                   "column": {
#                     "id": "single_select6__1",
#                     "title": "How accessible do you find the Tribe workspace in terms of location and transportation options?"
#                   },
#                   "text": "Very accessible"
#                 },
#                 {
#                   "id": "single_select66__1",
#                   "column": {
#                     "id": "single_select66__1",
#                     "title": "How would you describe the sense of the community within the Tribe workspace?"
#                   },
#                   "text": "Strong and supportive"
#                 },
#                 {
#                   "id": "long_text__1",
#                   "column": {
#                     "id": "long_text__1",
#                     "title": "What improvements or additions would you like to see in the Tribe workspace to enhance your experience?"
#                   },
#                   "text": "Bigger collaborative space :) "
#                 }
#               ]
#             },
#             {
#               "id": "8995960965",
#               "name": "Incoming form answer",
#               "column_values": [
#                 {
#                   "id": "date__1",
#                   "column": {
#                     "id": "date__1",
#                     "title": "Visit date?"
#                   },
#                   "text": "2025-04-24"
#                 },
#                 {
#                   "id": "single_select__1",
#                   "column": {
#                     "id": "single_select__1",
#                     "title": "Have you visited the Tribe workspace before?"
#                   },
#                   "text": "Yes"
#                 },
#                 {
#                   "id": "single_select1__1",
#                   "column": {
#                     "id": "single_select1__1",
#                     "title": "How would you rate the overall comfort and atmosphere of the Tribe workspace?"
#                   },
#                   "text": "Excellent"
#                 },
#                 {
#                   "id": "multi_select__1",
#                   "column": {
#                     "id": "multi_select__1",
#                     "title": "Which of the following amenities do you find most valuable in the Tribe workspace? (Select all that apply)"
#                   },
#                   "text": "Collaboration spaces"
#                 },
#                 {
#                   "id": "single_select6__1",
#                   "column": {
#                     "id": "single_select6__1",
#                     "title": "How accessible do you find the Tribe workspace in terms of location and transportation options?"
#                   },
#                   "text": "Very accessible"
#                 },
#                 {
#                   "id": "single_select66__1",
#                   "column": {
#                     "id": "single_select66__1",
#                     "title": "How would you describe the sense of the community within the Tribe workspace?"
#                   },
#                   "text": "Moderate and welcoming"
#                 },
#                 {
#                   "id": "long_text__1",
#                   "column": {
#                     "id": "long_text__1",
#                     "title": "What improvements or additions would you like to see in the Tribe workspace to enhance your experience?"
#                   },
#                   "text": ""
#                 }
#               ]
#             },
#             {
#               "id": "8995963343",
#               "name": "Incoming form answer",
#               "column_values": [
#                 {
#                   "id": "date__1",
#                   "column": {
#                     "id": "date__1",
#                     "title": "Visit date?"
#                   },
#                   "text": "2025-04-24"
#                 },
#                 {
#                   "id": "single_select__1",
#                   "column": {
#                     "id": "single_select__1",
#                     "title": "Have you visited the Tribe workspace before?"
#                   },
#                   "text": "Yes"
#                 },
#                 {
#                   "id": "single_select1__1",
#                   "column": {
#                     "id": "single_select1__1",
#                     "title": "How would you rate the overall comfort and atmosphere of the Tribe workspace?"
#                   },
#                   "text": "Fair"
#                 },
#                 {
#                   "id": "multi_select__1",
#                   "column": {
#                     "id": "multi_select__1",
#                     "title": "Which of the following amenities do you find most valuable in the Tribe workspace? (Select all that apply)"
#                   },
#                   "text": "Collaboration spaces"
#                 },
#                 {
#                   "id": "single_select6__1",
#                   "column": {
#                     "id": "single_select6__1",
#                     "title": "How accessible do you find the Tribe workspace in terms of location and transportation options?"
#                   },
#                   "text": "Not accessible at all"
#                 },
#                 {
#                   "id": "single_select66__1",
#                   "column": {
#                     "id": "single_select66__1",
#                     "title": "How would you describe the sense of the community within the Tribe workspace?"
#                   },
#                   "text": "Moderate and welcoming"
#                 },
#                 {
#                   "id": "long_text__1",
#                   "column": {
#                     "id": "long_text__1",
#                     "title": "What improvements or additions would you like to see in the Tribe workspace to enhance your experience?"
#                   },
#                   "text": "elevator.."
#                 }
#               ]
#             },
#             {
#               "id": "8995995290",
#               "name": "Incoming form answer",
#               "column_values": [
#                 {
#                   "id": "date__1",
#                   "column": {
#                     "id": "date__1",
#                     "title": "Visit date?"
#                   },
#                   "text": "2025-04-24"
#                 },
#                 {
#                   "id": "single_select__1",
#                   "column": {
#                     "id": "single_select__1",
#                     "title": "Have you visited the Tribe workspace before?"
#                   },
#                   "text": "No"
#                 },
#                 {
#                   "id": "single_select1__1",
#                   "column": {
#                     "id": "single_select1__1",
#                     "title": "How would you rate the overall comfort and atmosphere of the Tribe workspace?"
#                   },
#                   "text": "Excellent"
#                 },
#                 {
#                   "id": "multi_select__1",
#                   "column": {
#                     "id": "multi_select__1",
#                     "title": "Which of the following amenities do you find most valuable in the Tribe workspace? (Select all that apply)"
#                   },
#                   "text": "Collaboration spaces"
#                 },
#                 {
#                   "id": "single_select6__1",
#                   "column": {
#                     "id": "single_select6__1",
#                     "title": "How accessible do you find the Tribe workspace in terms of location and transportation options?"
#                   },
#                   "text": "Very accessible"
#                 },
#                 {
#                   "id": "single_select66__1",
#                   "column": {
#                     "id": "single_select66__1",
#                     "title": "How would you describe the sense of the community within the Tribe workspace?"
#                   },
#                   "text": "Strong and supportive"
#                 },
#                 {
#                   "id": "long_text__1",
#                   "column": {
#                     "id": "long_text__1",
#                     "title": "What improvements or additions would you like to see in the Tribe workspace to enhance your experience?"
#                   },
#                   "text": ""
#                 }
#               ]
#             },
#             {
#               "id": "8996562638",
#               "name": "Incoming form answer",
#               "column_values": [
#                 {
#                   "id": "date__1",
#                   "column": {
#                     "id": "date__1",
#                     "title": "Visit date?"
#                   },
#                   "text": "2025-04-24"
#                 },
#                 {
#                   "id": "single_select__1",
#                   "column": {
#                     "id": "single_select__1",
#                     "title": "Have you visited the Tribe workspace before?"
#                   },
#                   "text": "No"
#                 },
#                 {
#                   "id": "single_select1__1",
#                   "column": {
#                     "id": "single_select1__1",
#                     "title": "How would you rate the overall comfort and atmosphere of the Tribe workspace?"
#                   },
#                   "text": "Good"
#                 },
#                 {
#                   "id": "multi_select__1",
#                   "column": {
#                     "id": "multi_select__1",
#                     "title": "Which of the following amenities do you find most valuable in the Tribe workspace? (Select all that apply)"
#                   },
#                   "text": "Collaboration spaces, Refreshment options (e.g., coffee, snacks), Quiet work areas"
#                 },
#                 {
#                   "id": "single_select6__1",
#                   "column": {
#                     "id": "single_select6__1",
#                     "title": "How accessible do you find the Tribe workspace in terms of location and transportation options?"
#                   },
#                   "text": "Very accessible"
#                 },
#                 {
#                   "id": "single_select66__1",
#                   "column": {
#                     "id": "single_select66__1",
#                     "title": "How would you describe the sense of the community within the Tribe workspace?"
#                   },
#                   "text": "Strong and supportive"
#                 },
#                 {
#                   "id": "long_text__1",
#                   "column": {
#                     "id": "long_text__1",
#                     "title": "What improvements or additions would you like to see in the Tribe workspace to enhance your experience?"
#                   },
#                   "text": "Everything is just suitable and on a high level"
#                 }
#               ]
#             },
#             {
#               "id": "8997657517",
#               "name": "Incoming form answer",
#               "column_values": [
#                 {
#                   "id": "date__1",
#                   "column": {
#                     "id": "date__1",
#                     "title": "Visit date?"
#                   },
#                   "text": "2025-04-24"
#                 },
#                 {
#                   "id": "single_select__1",
#                   "column": {
#                     "id": "single_select__1",
#                     "title": "Have you visited the Tribe workspace before?"
#                   },
#                   "text": "Yes"
#                 },
#                 {
#                   "id": "single_select1__1",
#                   "column": {
#                     "id": "single_select1__1",
#                     "title": "How would you rate the overall comfort and atmosphere of the Tribe workspace?"
#                   },
#                   "text": "Excellent"
#                 },
#                 {
#                   "id": "multi_select__1",
#                   "column": {
#                     "id": "multi_select__1",
#                     "title": "Which of the following amenities do you find most valuable in the Tribe workspace? (Select all that apply)"
#                   },
#                   "text": "Collaboration spaces"
#                 },
#                 {
#                   "id": "single_select6__1",
#                   "column": {
#                     "id": "single_select6__1",
#                     "title": "How accessible do you find the Tribe workspace in terms of location and transportation options?"
#                   },
#                   "text": "Very accessible"
#                 },
#                 {
#                   "id": "single_select66__1",
#                   "column": {
#                     "id": "single_select66__1",
#                     "title": "How would you describe the sense of the community within the Tribe workspace?"
#                   },
#                   "text": "Moderate and welcoming"
#                 },
#                 {
#                   "id": "long_text__1",
#                   "column": {
#                     "id": "long_text__1",
#                     "title": "What improvements or additions would you like to see in the Tribe workspace to enhance your experience?"
#                   },
#                   "text": ""
#                 }
#               ]
#             }
#           ]
#         }
#       }
#     ]
#   }
# }

# %%
data = pd.DataFrame(rows)
data
# Out:
#             id                  name Visit date?  \
# 0   6765358368  Incoming form answer  2024-06-04
# 1   6765364436  Incoming form answer  2024-06-04
# 2   6765853286  Incoming form answer  2024-06-04
# 3   6766178199  Incoming form answer  2024-06-04
# 4   8995951295  Incoming form answer  2025-04-24
# 5   8995951868  Incoming form answer  2025-04-24
# 6   8995955041  Incoming form answer  2025-04-24
# 7   8995956945  Incoming form answer  2025-04-24
# 8   8995957691  Incoming form answer  2025-04-24
# 9   8995960412  Incoming form answer  2025-04-24
# 10  8995960965  Incoming form answer  2025-04-24
# 11  8995963343  Incoming form answer  2025-04-24
# 12  8995995290  Incoming form answer  2025-04-24
# 13  8996562638  Incoming form answer  2025-04-24
# 14  8997657517  Incoming form answer  2025-04-24
#
#    Have you visited the Tribe workspace before?  \
# 0                                           Yes
# 1                                           Yes
# 2                                           Yes
# 3                                           Yes
# 4                                            No
# 5                                            No
# 6                                            No
# 7                                            No
# 8                                            No
# 9                                            No
# 10                                          Yes
# 11                                          Yes
# 12                                           No
# 13                                           No
# 14                                          Yes
#
#    How would you rate the overall comfort and atmosphere of the Tribe workspace?  \
# 0                                           Excellent
# 1                                           Excellent
# 2                                           Excellent
# 3                                           Excellent
# 4                                           Excellent
# 5                                                Good
# 6                                           Excellent
# 7                                                Good
# 8                                                Good
# 9                                           Excellent
# 10                                          Excellent
# 11                                               Fair
# 12                                          Excellent
# 13                                               Good
# 14                                          Excellent
#
#    Which of the following amenities do you find most valuable in the Tribe workspace? (Select all that apply)  \
# 0   Collaboration spaces, Refreshment options (e.g...
# 1   Refreshment options (e.g., coffee, snacks), Pr...
# 2                                 High-speed internet
# 3                                Collaboration spaces
# 4   High-speed internet, Quiet work areas, Collabo...
# 5                                Collaboration spaces
# 6   High-speed internet, Refreshment options (e.g....
# 7                                    Quiet work areas
# 8                                Collaboration spaces
# 9        Other (please specify), Collaboration spaces
# 10                               Collaboration spaces
# 11                               Collaboration spaces
# 12                               Collaboration spaces
# 13  Collaboration spaces, Refreshment options (e.g...
# 14                               Collaboration spaces
#
#    How accessible do you find the Tribe workspace in terms of location and transportation options?  \
# 0                                     Very accessible
# 1                                     Very accessible
# 2                                     Very accessible
# 3                                     Very accessible
# 4                                     Very accessible
# 5                                 Somewhat accessible
# 6                                 Somewhat accessible
# 7                                     Very accessible
# 8                                     Very accessible
# 9                                     Very accessible
# 10                                    Very accessible
# 11                              Not accessible at all
# 12                                    Very accessible
# 13                                    Very accessible
# 14                                    Very accessible
#
#    How would you describe the sense of the community within the Tribe workspace?  \
# 0                               Strong and supportive
# 1                               Strong and supportive
# 2                               Strong and supportive
# 3                               Strong and supportive
# 4                               Strong and supportive
# 5                              Moderate and welcoming
# 6                              Moderate and welcoming
# 7                               Strong and supportive
# 8                               Strong and supportive
# 9                               Strong and supportive
# 10                             Moderate and welcoming
# 11                             Moderate and welcoming
# 12                              Strong and supportive
# 13                              Strong and supportive
# 14                             Moderate and welcoming
#
#    What improvements or additions would you like to see in the Tribe workspace to enhance your experience?
# 0   Air conditioning (more fans etc.).\nCheck that...
# 1   Internet speed is only my negative feedback bu...
# 2                     Maybe more small meeting rooms?
# 3
# 4
# 5
# 6
# 7
# 8
# 9                      Bigger collaborative space :)
# 10
# 11                                         elevator..
# 12
# 13    Everything is just suitable and on a high level
# 14
