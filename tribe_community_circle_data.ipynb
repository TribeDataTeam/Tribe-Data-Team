# %%
import numpy as np
import pandas as pd
import requests
import json

# %%
api_key = 'eyJhbGciOiJIUzI1NiJ9.eyJ0aWQiOjUwMjA4MDk5NSwiYWFpIjoxMSwidWlkIjozMTY2NzY3MCwiaWFkIjoiMjAyNS0wNC0yMFQxMjoxNzo0MC40MDFaIiwicGVyIjoibWU6d3JpdGUiLCJhY3RpZCI6MTI2MjUwMzAsInJnbiI6InVzZTEifQ.EqePBq-dzRrAMUz8NzoLHe_7YIZWgBdHv1M-he6cb3U'
board_no = '5827875364'

headers = {
    "Authorization": api_key,
    "Content-Type": "application/json"
}

query = """
query {
        boards (ids : %s) {
            items_page (limit : 200){
                items{
                    id
                    name
                    column_values{
                        id
                        column{
                            id
                            title
                            }
                        text
                    }
                }
            }
        }
    }
""" % board_no

response = requests.post (url ="https://api.monday.com/v2",
                          json= {"query" : query}, headers= headers)
if response.status_code == 200:
    com_data = response.json()
    print(json.dumps(com_data, indent= 2))
else:
    print ("Error:", response.status_code, response.text)

rows = []

for item in com_data["data"]["boards"][0]["items_page"]["items"]:
    row = {
        "id" : item["id"],
        "name": item["name"],
        
    }
    for col in item["column_values"]:
        row[col["column"]["title"]] = col["text"]
    
    rows.append(row)
# Out:
# {
#   "data": {
#     "boards": [
#       {
#         "items_page": {
#           "items": [
#             {
#               "id": "7415202559",
#               "name": "Incoming form answer",
#               "column_values": [
#                 {
#                   "id": "short_text_1",
#                   "column": {
#                     "id": "short_text_1",
#                     "title": "Name"
#                   },
#                   "text": "Dmytro"
#                 },
#                 {
#                   "id": "status",
#                   "column": {
#                     "id": "status",
#                     "title": "Status"
#                   },
#                   "text": "Did not show up/canceled"
#                 },
#                 {
#                   "id": "date",
#                   "column": {
#                     "id": "date",
#                     "title": "Date of Application"
#                   },
#                   "text": "2024-09-12"
#                 },
#                 {
#                   "id": "date_mknfqhv",
#                   "column": {
#                     "id": "date_mknfqhv",
#                     "title": "Email Date"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "single_select5",
#                   "column": {
#                     "id": "single_select5",
#                     "title": "Do you want to continue in Tribe Fellowship?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "short_text_19",
#                   "column": {
#                     "id": "short_text_19",
#                     "title": "email"
#                   },
#                   "text": "Pradovd4@gmail.com"
#                 },
#                 {
#                   "id": "color_mkpkbmej",
#                   "column": {
#                     "id": "color_mkpkbmej",
#                     "title": "Do you have a startup/business idea that you want to work on?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "long_text_mkpkjb81",
#                   "column": {
#                     "id": "long_text_mkpkjb81",
#                     "title": "Describe the idea or a project that you are building on."
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "color_mkpk4rqx",
#                   "column": {
#                     "id": "color_mkpk4rqx",
#                     "title": "Which stage/target group do you belong to?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "dropdown_mkpkhmhy",
#                   "column": {
#                     "id": "dropdown_mkpkhmhy",
#                     "title": "What is your progress so far?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "long_text_mkpkv1w3",
#                   "column": {
#                     "id": "long_text_mkpkv1w3",
#                     "title": "What are you next steps for your project?"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "long_text_mkpk73d3",
#                   "column": {
#                     "id": "long_text_mkpk73d3",
#                     "title": "What skills do you feel like you need to develop to take your project forward?"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "dropdown_mkpkgsye",
#                   "column": {
#                     "id": "dropdown_mkpkgsye",
#                     "title": "How do you want to be involved within the community?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "dropdown_mkpkgwyx",
#                   "column": {
#                     "id": "dropdown_mkpkgwyx",
#                     "title": "What skills are you looking forward to developing by joining the Fellowship?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "dropdown_mkpkhks1",
#                   "column": {
#                     "id": "dropdown_mkpkhks1",
#                     "title": "What attributes are you aiming to get through Fellowship?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "text_mkpkw7n4",
#                   "column": {
#                     "id": "text_mkpkw7n4",
#                     "title": "Write an attribute you like to get through the fellowship"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "text_mkpkzdfh",
#                   "column": {
#                     "id": "text_mkpkzdfh",
#                     "title": "Write here other skills you would like to develop"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "multi_select5",
#                   "column": {
#                     "id": "multi_select5",
#                     "title": "What part of the community circle are you most interested in?"
#                   },
#                   "text": "I am not sure"
#                 },
#                 {
#                   "id": "multi_select01",
#                   "column": {
#                     "id": "multi_select01",
#                     "title": "What skills are you looking forward to developing during your time in the Community Circle"
#                   },
#                   "text": "IT skills"
#                 },
#                 {
#                   "id": "multi_select6",
#                   "column": {
#                     "id": "multi_select6",
#                     "title": "What attributes are you aiming to get through the Community Circle?"
#                   },
#                   "text": "Employment in the startup ecosystem"
#                 },
#                 {
#                   "id": "short_text45",
#                   "column": {
#                     "id": "short_text45",
#                     "title": "Where or from whom did you hear about Fellowship?"
#                   },
#                   "text": "From TE office"
#                 },
#                 {
#                   "id": "short_text3",
#                   "column": {
#                     "id": "short_text3",
#                     "title": "Anything else you want to tell us? (achievements, expectations, goals, needs.....?)"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "date2",
#                   "column": {
#                     "id": "date2",
#                     "title": "Date of onboarding"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "short_text6",
#                   "column": {
#                     "id": "short_text6",
#                     "title": "What traits/skills have you been able to improve/develop during your time in Fellowship?"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "short_text39",
#                   "column": {
#                     "id": "short_text39",
#                     "title": "What have you accomplished during 6 months in Fellowship?"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "short_text29",
#                   "column": {
#                     "id": "short_text29",
#                     "title": "Highlight some experiences in the last 6 months (3 favorite moments/events/achievements/learnings\u2026)"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "single_select57",
#                   "column": {
#                     "id": "single_select57",
#                     "title": "How likely would you recommend Tribe Fellowship (Startup Catalyst or Community Circle) to a friend on a scale of 1-10 (1 lowest, 10 highest)"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "single_select0",
#                   "column": {
#                     "id": "single_select0",
#                     "title": "How likely would you recommend the Tribe community to a friend on a scale of 1-10 (1 lowest, 10 highest)"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "short_text60",
#                   "column": {
#                     "id": "short_text60",
#                     "title": "Open feedback :)"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "true___false9",
#                   "column": {
#                     "id": "true___false9",
#                     "title": "Privacy policy\n\nWe need your consent to the storage and processing of your data in accordance with the privacy statement. \nCheck it out here: tribetampere.com/privacy-statement"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "short_text76",
#                   "column": {
#                     "id": "short_text76",
#                     "title": "What do you want to accomplish in the next 6 months in Fellowship?"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "single_select7",
#                   "column": {
#                     "id": "single_select7",
#                     "title": "Have you moved to another program/organization/position/other?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "short_text18",
#                   "column": {
#                     "id": "short_text18",
#                     "title": "Where have you moved on to?"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "short_text93",
#                   "column": {
#                     "id": "short_text93",
#                     "title": "What are your future plans?"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "single_select",
#                   "column": {
#                     "id": "single_select",
#                     "title": "How likely would you recommend Tribe Fellowship (Startup Catalyst or Community Circle) to a friend on a scale of 1-10"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "single_select3",
#                   "column": {
#                     "id": "single_select3",
#                     "title": "How likely would you recommend the Tribe community to a friend on a scale of 1-10 (10 highest, 1 lowest)"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "short_text0",
#                   "column": {
#                     "id": "short_text0",
#                     "title": "What would you need or expect from Tribe in the future to support you? (More actions, events, interactions, gatherings, guidance..?)"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "single_select6",
#                   "column": {
#                     "id": "single_select6",
#                     "title": "Are you continuing in Tribe Fellowship?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "short_text2",
#                   "column": {
#                     "id": "short_text2",
#                     "title": "What would you need or expect from Tribe in the future to support you? (More actions, events, interactions, gatherings, guidance..?)"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "multi_select9",
#                   "column": {
#                     "id": "multi_select9",
#                     "title": "In what ways have you been engaged in the community? You can choose multiple options."
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "short_text9",
#                   "column": {
#                     "id": "short_text9",
#                     "title": "Following some additional questions regarding basic information for us to understand the target group of Fellowship better:\n\nWhat nationality or nationalities do you hold?"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "single_select1",
#                   "column": {
#                     "id": "single_select1",
#                     "title": "How do you identify yourself?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "single_select9",
#                   "column": {
#                     "id": "single_select9",
#                     "title": "To what age range do you belong to?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "single_select4",
#                   "column": {
#                     "id": "single_select4",
#                     "title": "What is your current occupation?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "true___false6",
#                   "column": {
#                     "id": "true___false6",
#                     "title": "Privacy policy\n\nWe need your consent to the storage and processing of your data in accordance with the privacy statement. \n\nCheck it out here: tribetampere.com/privacy-statement"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "short_text10",
#                   "column": {
#                     "id": "short_text10",
#                     "title": "Please spesify:"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "subitems",
#                   "column": {
#                     "id": "subitems",
#                     "title": "Subitems"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "text",
#                   "column": {
#                     "id": "text",
#                     "title": "Impact/notes"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "short_text1",
#                   "column": {
#                     "id": "short_text1",
#                     "title": "Write down what other attributes would you like to get through the community circle."
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "short_text7",
#                   "column": {
#                     "id": "short_text7",
#                     "title": "Write here other skills you would like to develop."
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "true___false",
#                   "column": {
#                     "id": "true___false",
#                     "title": "Privacy policy"
#                   },
#                   "text": "v"
#                 },
#                 {
#                   "id": "true___false3",
#                   "column": {
#                     "id": "true___false3",
#                     "title": "Do you live in Tampere area?"
#                   },
#                   "text": "v"
#                 }
#               ]
#             },
#             {
#               "id": "7691210593",
#               "name": "Incoming form answer",
#               "column_values": [
#                 {
#                   "id": "short_text_1",
#                   "column": {
#                     "id": "short_text_1",
#                     "title": "Name"
#                   },
#                   "text": "Deniz Turan"
#                 },
#                 {
#                   "id": "status",
#                   "column": {
#                     "id": "status",
#                     "title": "Status"
#                   },
#                   "text": "Did not show up/canceled"
#                 },
#                 {
#                   "id": "date",
#                   "column": {
#                     "id": "date",
#                     "title": "Date of Application"
#                   },
#                   "text": "2024-10-23"
#                 },
#                 {
#                   "id": "date_mknfqhv",
#                   "column": {
#                     "id": "date_mknfqhv",
#                     "title": "Email Date"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "single_select5",
#                   "column": {
#                     "id": "single_select5",
#                     "title": "Do you want to continue in Tribe Fellowship?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "short_text_19",
#                   "column": {
#                     "id": "short_text_19",
#                     "title": "email"
#                   },
#                   "text": "denizturan905@gmail.com"
#                 },
#                 {
#                   "id": "color_mkpkbmej",
#                   "column": {
#                     "id": "color_mkpkbmej",
#                     "title": "Do you have a startup/business idea that you want to work on?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "long_text_mkpkjb81",
#                   "column": {
#                     "id": "long_text_mkpkjb81",
#                     "title": "Describe the idea or a project that you are building on."
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "color_mkpk4rqx",
#                   "column": {
#                     "id": "color_mkpk4rqx",
#                     "title": "Which stage/target group do you belong to?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "dropdown_mkpkhmhy",
#                   "column": {
#                     "id": "dropdown_mkpkhmhy",
#                     "title": "What is your progress so far?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "long_text_mkpkv1w3",
#                   "column": {
#                     "id": "long_text_mkpkv1w3",
#                     "title": "What are you next steps for your project?"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "long_text_mkpk73d3",
#                   "column": {
#                     "id": "long_text_mkpk73d3",
#                     "title": "What skills do you feel like you need to develop to take your project forward?"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "dropdown_mkpkgsye",
#                   "column": {
#                     "id": "dropdown_mkpkgsye",
#                     "title": "How do you want to be involved within the community?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "dropdown_mkpkgwyx",
#                   "column": {
#                     "id": "dropdown_mkpkgwyx",
#                     "title": "What skills are you looking forward to developing by joining the Fellowship?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "dropdown_mkpkhks1",
#                   "column": {
#                     "id": "dropdown_mkpkhks1",
#                     "title": "What attributes are you aiming to get through Fellowship?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "text_mkpkw7n4",
#                   "column": {
#                     "id": "text_mkpkw7n4",
#                     "title": "Write an attribute you like to get through the fellowship"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "text_mkpkzdfh",
#                   "column": {
#                     "id": "text_mkpkzdfh",
#                     "title": "Write here other skills you would like to develop"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "multi_select5",
#                   "column": {
#                     "id": "multi_select5",
#                     "title": "What part of the community circle are you most interested in?"
#                   },
#                   "text": "Operational Team, Events, Challenges, Networking"
#                 },
#                 {
#                   "id": "multi_select01",
#                   "column": {
#                     "id": "multi_select01",
#                     "title": "What skills are you looking forward to developing during your time in the Community Circle"
#                   },
#                   "text": "IT skills"
#                 },
#                 {
#                   "id": "multi_select6",
#                   "column": {
#                     "id": "multi_select6",
#                     "title": "What attributes are you aiming to get through the Community Circle?"
#                   },
#                   "text": "Co-Founders"
#                 },
#                 {
#                   "id": "short_text45",
#                   "column": {
#                     "id": "short_text45",
#                     "title": "Where or from whom did you hear about Fellowship?"
#                   },
#                   "text": "From the internet site"
#                 },
#                 {
#                   "id": "short_text3",
#                   "column": {
#                     "id": "short_text3",
#                     "title": "Anything else you want to tell us? (achievements, expectations, goals, needs.....?)"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "date2",
#                   "column": {
#                     "id": "date2",
#                     "title": "Date of onboarding"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "short_text6",
#                   "column": {
#                     "id": "short_text6",
#                     "title": "What traits/skills have you been able to improve/develop during your time in Fellowship?"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "short_text39",
#                   "column": {
#                     "id": "short_text39",
#                     "title": "What have you accomplished during 6 months in Fellowship?"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "short_text29",
#                   "column": {
#                     "id": "short_text29",
#                     "title": "Highlight some experiences in the last 6 months (3 favorite moments/events/achievements/learnings\u2026)"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "single_select57",
#                   "column": {
#                     "id": "single_select57",
#                     "title": "How likely would you recommend Tribe Fellowship (Startup Catalyst or Community Circle) to a friend on a scale of 1-10 (1 lowest, 10 highest)"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "single_select0",
#                   "column": {
#                     "id": "single_select0",
#                     "title": "How likely would you recommend the Tribe community to a friend on a scale of 1-10 (1 lowest, 10 highest)"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "short_text60",
#                   "column": {
#                     "id": "short_text60",
#                     "title": "Open feedback :)"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "true___false9",
#                   "column": {
#                     "id": "true___false9",
#                     "title": "Privacy policy\n\nWe need your consent to the storage and processing of your data in accordance with the privacy statement. \nCheck it out here: tribetampere.com/privacy-statement"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "short_text76",
#                   "column": {
#                     "id": "short_text76",
#                     "title": "What do you want to accomplish in the next 6 months in Fellowship?"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "single_select7",
#                   "column": {
#                     "id": "single_select7",
#                     "title": "Have you moved to another program/organization/position/other?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "short_text18",
#                   "column": {
#                     "id": "short_text18",
#                     "title": "Where have you moved on to?"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "short_text93",
#                   "column": {
#                     "id": "short_text93",
#                     "title": "What are your future plans?"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "single_select",
#                   "column": {
#                     "id": "single_select",
#                     "title": "How likely would you recommend Tribe Fellowship (Startup Catalyst or Community Circle) to a friend on a scale of 1-10"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "single_select3",
#                   "column": {
#                     "id": "single_select3",
#                     "title": "How likely would you recommend the Tribe community to a friend on a scale of 1-10 (10 highest, 1 lowest)"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "short_text0",
#                   "column": {
#                     "id": "short_text0",
#                     "title": "What would you need or expect from Tribe in the future to support you? (More actions, events, interactions, gatherings, guidance..?)"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "single_select6",
#                   "column": {
#                     "id": "single_select6",
#                     "title": "Are you continuing in Tribe Fellowship?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "short_text2",
#                   "column": {
#                     "id": "short_text2",
#                     "title": "What would you need or expect from Tribe in the future to support you? (More actions, events, interactions, gatherings, guidance..?)"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "multi_select9",
#                   "column": {
#                     "id": "multi_select9",
#                     "title": "In what ways have you been engaged in the community? You can choose multiple options."
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "short_text9",
#                   "column": {
#                     "id": "short_text9",
#                     "title": "Following some additional questions regarding basic information for us to understand the target group of Fellowship better:\n\nWhat nationality or nationalities do you hold?"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "single_select1",
#                   "column": {
#                     "id": "single_select1",
#                     "title": "How do you identify yourself?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "single_select9",
#                   "column": {
#                     "id": "single_select9",
#                     "title": "To what age range do you belong to?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "single_select4",
#                   "column": {
#                     "id": "single_select4",
#                     "title": "What is your current occupation?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "true___false6",
#                   "column": {
#                     "id": "true___false6",
#                     "title": "Privacy policy\n\nWe need your consent to the storage and processing of your data in accordance with the privacy statement. \n\nCheck it out here: tribetampere.com/privacy-statement"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "short_text10",
#                   "column": {
#                     "id": "short_text10",
#                     "title": "Please spesify:"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "subitems",
#                   "column": {
#                     "id": "subitems",
#                     "title": "Subitems"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "text",
#                   "column": {
#                     "id": "text",
#                     "title": "Impact/notes"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "short_text1",
#                   "column": {
#                     "id": "short_text1",
#                     "title": "Write down what other attributes would you like to get through the community circle."
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "short_text7",
#                   "column": {
#                     "id": "short_text7",
#                     "title": "Write here other skills you would like to develop."
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "true___false",
#                   "column": {
#                     "id": "true___false",
#                     "title": "Privacy policy"
#                   },
#                   "text": "v"
#                 },
#                 {
#                   "id": "true___false3",
#                   "column": {
#                     "id": "true___false3",
#                     "title": "Do you live in Tampere area?"
#                   },
#                   "text": "v"
#                 }
#               ]
#             },
#             {
#               "id": "7693180568",
#               "name": "Incoming form answer",
#               "column_values": [
#                 {
#                   "id": "short_text_1",
#                   "column": {
#                     "id": "short_text_1",
#                     "title": "Name"
#                   },
#                   "text": "Selene Gama"
#                 },
#                 {
#                   "id": "status",
#                   "column": {
#                     "id": "status",
#                     "title": "Status"
#                   },
#                   "text": "Did not show up/canceled"
#                 },
#                 {
#                   "id": "date",
#                   "column": {
#                     "id": "date",
#                     "title": "Date of Application"
#                   },
#                   "text": "2024-10-23"
#                 },
#                 {
#                   "id": "date_mknfqhv",
#                   "column": {
#                     "id": "date_mknfqhv",
#                     "title": "Email Date"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "single_select5",
#                   "column": {
#                     "id": "single_select5",
#                     "title": "Do you want to continue in Tribe Fellowship?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "short_text_19",
#                   "column": {
#                     "id": "short_text_19",
#                     "title": "email"
#                   },
#                   "text": "selenegama.br@gmail.com"
#                 },
#                 {
#                   "id": "color_mkpkbmej",
#                   "column": {
#                     "id": "color_mkpkbmej",
#                     "title": "Do you have a startup/business idea that you want to work on?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "long_text_mkpkjb81",
#                   "column": {
#                     "id": "long_text_mkpkjb81",
#                     "title": "Describe the idea or a project that you are building on."
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "color_mkpk4rqx",
#                   "column": {
#                     "id": "color_mkpk4rqx",
#                     "title": "Which stage/target group do you belong to?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "dropdown_mkpkhmhy",
#                   "column": {
#                     "id": "dropdown_mkpkhmhy",
#                     "title": "What is your progress so far?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "long_text_mkpkv1w3",
#                   "column": {
#                     "id": "long_text_mkpkv1w3",
#                     "title": "What are you next steps for your project?"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "long_text_mkpk73d3",
#                   "column": {
#                     "id": "long_text_mkpk73d3",
#                     "title": "What skills do you feel like you need to develop to take your project forward?"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "dropdown_mkpkgsye",
#                   "column": {
#                     "id": "dropdown_mkpkgsye",
#                     "title": "How do you want to be involved within the community?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "dropdown_mkpkgwyx",
#                   "column": {
#                     "id": "dropdown_mkpkgwyx",
#                     "title": "What skills are you looking forward to developing by joining the Fellowship?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "dropdown_mkpkhks1",
#                   "column": {
#                     "id": "dropdown_mkpkhks1",
#                     "title": "What attributes are you aiming to get through Fellowship?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "text_mkpkw7n4",
#                   "column": {
#                     "id": "text_mkpkw7n4",
#                     "title": "Write an attribute you like to get through the fellowship"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "text_mkpkzdfh",
#                   "column": {
#                     "id": "text_mkpkzdfh",
#                     "title": "Write here other skills you would like to develop"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "multi_select5",
#                   "column": {
#                     "id": "multi_select5",
#                     "title": "What part of the community circle are you most interested in?"
#                   },
#                   "text": "Networking"
#                 },
#                 {
#                   "id": "multi_select01",
#                   "column": {
#                     "id": "multi_select01",
#                     "title": "What skills are you looking forward to developing during your time in the Community Circle"
#                   },
#                   "text": "Problem-solving"
#                 },
#                 {
#                   "id": "multi_select6",
#                   "column": {
#                     "id": "multi_select6",
#                     "title": "What attributes are you aiming to get through the Community Circle?"
#                   },
#                   "text": "Build partnerships between organizations"
#                 },
#                 {
#                   "id": "short_text45",
#                   "column": {
#                     "id": "short_text45",
#                     "title": "Where or from whom did you hear about Fellowship?"
#                   },
#                   "text": "Tribe activities"
#                 },
#                 {
#                   "id": "short_text3",
#                   "column": {
#                     "id": "short_text3",
#                     "title": "Anything else you want to tell us? (achievements, expectations, goals, needs.....?)"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "date2",
#                   "column": {
#                     "id": "date2",
#                     "title": "Date of onboarding"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "short_text6",
#                   "column": {
#                     "id": "short_text6",
#                     "title": "What traits/skills have you been able to improve/develop during your time in Fellowship?"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "short_text39",
#                   "column": {
#                     "id": "short_text39",
#                     "title": "What have you accomplished during 6 months in Fellowship?"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "short_text29",
#                   "column": {
#                     "id": "short_text29",
#                     "title": "Highlight some experiences in the last 6 months (3 favorite moments/events/achievements/learnings\u2026)"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "single_select57",
#                   "column": {
#                     "id": "single_select57",
#                     "title": "How likely would you recommend Tribe Fellowship (Startup Catalyst or Community Circle) to a friend on a scale of 1-10 (1 lowest, 10 highest)"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "single_select0",
#                   "column": {
#                     "id": "single_select0",
#                     "title": "How likely would you recommend the Tribe community to a friend on a scale of 1-10 (1 lowest, 10 highest)"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "short_text60",
#                   "column": {
#                     "id": "short_text60",
#                     "title": "Open feedback :)"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "true___false9",
#                   "column": {
#                     "id": "true___false9",
#                     "title": "Privacy policy\n\nWe need your consent to the storage and processing of your data in accordance with the privacy statement. \nCheck it out here: tribetampere.com/privacy-statement"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "short_text76",
#                   "column": {
#                     "id": "short_text76",
#                     "title": "What do you want to accomplish in the next 6 months in Fellowship?"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "single_select7",
#                   "column": {
#                     "id": "single_select7",
#                     "title": "Have you moved to another program/organization/position/other?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "short_text18",
#                   "column": {
#                     "id": "short_text18",
#                     "title": "Where have you moved on to?"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "short_text93",
#                   "column": {
#                     "id": "short_text93",
#                     "title": "What are your future plans?"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "single_select",
#                   "column": {
#                     "id": "single_select",
#                     "title": "How likely would you recommend Tribe Fellowship (Startup Catalyst or Community Circle) to a friend on a scale of 1-10"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "single_select3",
#                   "column": {
#                     "id": "single_select3",
#                     "title": "How likely would you recommend the Tribe community to a friend on a scale of 1-10 (10 highest, 1 lowest)"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "short_text0",
#                   "column": {
#                     "id": "short_text0",
#                     "title": "What would you need or expect from Tribe in the future to support you? (More actions, events, interactions, gatherings, guidance..?)"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "single_select6",
#                   "column": {
#                     "id": "single_select6",
#                     "title": "Are you continuing in Tribe Fellowship?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "short_text2",
#                   "column": {
#                     "id": "short_text2",
#                     "title": "What would you need or expect from Tribe in the future to support you? (More actions, events, interactions, gatherings, guidance..?)"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "multi_select9",
#                   "column": {
#                     "id": "multi_select9",
#                     "title": "In what ways have you been engaged in the community? You can choose multiple options."
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "short_text9",
#                   "column": {
#                     "id": "short_text9",
#                     "title": "Following some additional questions regarding basic information for us to understand the target group of Fellowship better:\n\nWhat nationality or nationalities do you hold?"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "single_select1",
#                   "column": {
#                     "id": "single_select1",
#                     "title": "How do you identify yourself?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "single_select9",
#                   "column": {
#                     "id": "single_select9",
#                     "title": "To what age range do you belong to?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "single_select4",
#                   "column": {
#                     "id": "single_select4",
#                     "title": "What is your current occupation?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "true___false6",
#                   "column": {
#                     "id": "true___false6",
#                     "title": "Privacy policy\n\nWe need your consent to the storage and processing of your data in accordance with the privacy statement. \n\nCheck it out here: tribetampere.com/privacy-statement"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "short_text10",
#                   "column": {
#                     "id": "short_text10",
#                     "title": "Please spesify:"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "subitems",
#                   "column": {
#                     "id": "subitems",
#                     "title": "Subitems"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "text",
#                   "column": {
#                     "id": "text",
#                     "title": "Impact/notes"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "short_text1",
#                   "column": {
#                     "id": "short_text1",
#                     "title": "Write down what other attributes would you like to get through the community circle."
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "short_text7",
#                   "column": {
#                     "id": "short_text7",
#                     "title": "Write here other skills you would like to develop."
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "true___false",
#                   "column": {
#                     "id": "true___false",
#                     "title": "Privacy policy"
#                   },
#                   "text": "v"
#                 },
#                 {
#                   "id": "true___false3",
#                   "column": {
#                     "id": "true___false3",
#                     "title": "Do you live in Tampere area?"
#                   },
#                   "text": "v"
#                 }
#               ]
#             },
#             {
#               "id": "7703148193",
#               "name": "Incoming form answer",
#               "column_values": [
#                 {
#                   "id": "short_text_1",
#                   "column": {
#                     "id": "short_text_1",
#                     "title": "Name"
#                   },
#                   "text": "Ifeoluwa Dosunmu"
#                 },
#                 {
#                   "id": "status",
#                   "column": {
#                     "id": "status",
#                     "title": "Status"
#                   },
#                   "text": "reminded to book"
#                 },
#                 {
#                   "id": "date",
#                   "column": {
#                     "id": "date",
#                     "title": "Date of Application"
#                   },
#                   "text": "2024-10-24"
#                 },
#                 {
#                   "id": "date_mknfqhv",
#                   "column": {
#                     "id": "date_mknfqhv",
#                     "title": "Email Date"
#                   },
# ...
#                   "column": {
#                     "id": "true___false3",
#                     "title": "Do you live in Tampere area?"
#                   },
#                   "text": ""
#                 }
#               ]
#             },
#             {
#               "id": "8436778916",
#               "name": "Incoming form answer",
#               "column_values": [
#                 {
#                   "id": "short_text_1",
#                   "column": {
#                     "id": "short_text_1",
#                     "title": "Name"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "status",
#                   "column": {
#                     "id": "status",
#                     "title": "Status"
#                   },
#                   "text": "Onboarding booked"
#                 },
#                 {
#                   "id": "date",
#                   "column": {
#                     "id": "date",
#                     "title": "Date of Application"
#                   },
#                   "text": "2025-02-09"
#                 },
#                 {
#                   "id": "date_mknfqhv",
#                   "column": {
#                     "id": "date_mknfqhv",
#                     "title": "Email Date"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "single_select5",
#                   "column": {
#                     "id": "single_select5",
#                     "title": "Do you want to continue in Tribe Fellowship?"
#                   },
#                   "text": "Yes"
#                 },
#                 {
#                   "id": "short_text_19",
#                   "column": {
#                     "id": "short_text_19",
#                     "title": "email"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "color_mkpkbmej",
#                   "column": {
#                     "id": "color_mkpkbmej",
#                     "title": "Do you have a startup/business idea that you want to work on?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "long_text_mkpkjb81",
#                   "column": {
#                     "id": "long_text_mkpkjb81",
#                     "title": "Describe the idea or a project that you are building on."
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "color_mkpk4rqx",
#                   "column": {
#                     "id": "color_mkpk4rqx",
#                     "title": "Which stage/target group do you belong to?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "dropdown_mkpkhmhy",
#                   "column": {
#                     "id": "dropdown_mkpkhmhy",
#                     "title": "What is your progress so far?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "long_text_mkpkv1w3",
#                   "column": {
#                     "id": "long_text_mkpkv1w3",
#                     "title": "What are you next steps for your project?"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "long_text_mkpk73d3",
#                   "column": {
#                     "id": "long_text_mkpk73d3",
#                     "title": "What skills do you feel like you need to develop to take your project forward?"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "dropdown_mkpkgsye",
#                   "column": {
#                     "id": "dropdown_mkpkgsye",
#                     "title": "How do you want to be involved within the community?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "dropdown_mkpkgwyx",
#                   "column": {
#                     "id": "dropdown_mkpkgwyx",
#                     "title": "What skills are you looking forward to developing by joining the Fellowship?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "dropdown_mkpkhks1",
#                   "column": {
#                     "id": "dropdown_mkpkhks1",
#                     "title": "What attributes are you aiming to get through Fellowship?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "text_mkpkw7n4",
#                   "column": {
#                     "id": "text_mkpkw7n4",
#                     "title": "Write an attribute you like to get through the fellowship"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "text_mkpkzdfh",
#                   "column": {
#                     "id": "text_mkpkzdfh",
#                     "title": "Write here other skills you would like to develop"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "multi_select5",
#                   "column": {
#                     "id": "multi_select5",
#                     "title": "What part of the community circle are you most interested in?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "multi_select01",
#                   "column": {
#                     "id": "multi_select01",
#                     "title": "What skills are you looking forward to developing during your time in the Community Circle"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "multi_select6",
#                   "column": {
#                     "id": "multi_select6",
#                     "title": "What attributes are you aiming to get through the Community Circle?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "short_text45",
#                   "column": {
#                     "id": "short_text45",
#                     "title": "Where or from whom did you hear about Fellowship?"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "short_text3",
#                   "column": {
#                     "id": "short_text3",
#                     "title": "Anything else you want to tell us? (achievements, expectations, goals, needs.....?)"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "date2",
#                   "column": {
#                     "id": "date2",
#                     "title": "Date of onboarding"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "short_text6",
#                   "column": {
#                     "id": "short_text6",
#                     "title": "What traits/skills have you been able to improve/develop during your time in Fellowship?"
#                   },
#                   "text": "Communication"
#                 },
#                 {
#                   "id": "short_text39",
#                   "column": {
#                     "id": "short_text39",
#                     "title": "What have you accomplished during 6 months in Fellowship?"
#                   },
#                   "text": "I joined with team of 7 individuals to start a business"
#                 },
#                 {
#                   "id": "short_text29",
#                   "column": {
#                     "id": "short_text29",
#                     "title": "Highlight some experiences in the last 6 months (3 favorite moments/events/achievements/learnings\u2026)"
#                   },
#                   "text": "I mostly enjoined start up meeting / competitions"
#                 },
#                 {
#                   "id": "single_select57",
#                   "column": {
#                     "id": "single_select57",
#                     "title": "How likely would you recommend Tribe Fellowship (Startup Catalyst or Community Circle) to a friend on a scale of 1-10 (1 lowest, 10 highest)"
#                   },
#                   "text": "10"
#                 },
#                 {
#                   "id": "single_select0",
#                   "column": {
#                     "id": "single_select0",
#                     "title": "How likely would you recommend the Tribe community to a friend on a scale of 1-10 (1 lowest, 10 highest)"
#                   },
#                   "text": "10"
#                 },
#                 {
#                   "id": "short_text60",
#                   "column": {
#                     "id": "short_text60",
#                     "title": "Open feedback :)"
#                   },
#                   "text": "I think you guys a doing a wonderful job :-)"
#                 },
#                 {
#                   "id": "true___false9",
#                   "column": {
#                     "id": "true___false9",
#                     "title": "Privacy policy\n\nWe need your consent to the storage and processing of your data in accordance with the privacy statement. \nCheck it out here: tribetampere.com/privacy-statement"
#                   },
#                   "text": "v"
#                 },
#                 {
#                   "id": "short_text76",
#                   "column": {
#                     "id": "short_text76",
#                     "title": "What do you want to accomplish in the next 6 months in Fellowship?"
#                   },
#                   "text": "I want to start my own business"
#                 },
#                 {
#                   "id": "single_select7",
#                   "column": {
#                     "id": "single_select7",
#                     "title": "Have you moved to another program/organization/position/other?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "short_text18",
#                   "column": {
#                     "id": "short_text18",
#                     "title": "Where have you moved on to?"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "short_text93",
#                   "column": {
#                     "id": "short_text93",
#                     "title": "What are your future plans?"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "single_select",
#                   "column": {
#                     "id": "single_select",
#                     "title": "How likely would you recommend Tribe Fellowship (Startup Catalyst or Community Circle) to a friend on a scale of 1-10"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "single_select3",
#                   "column": {
#                     "id": "single_select3",
#                     "title": "How likely would you recommend the Tribe community to a friend on a scale of 1-10 (10 highest, 1 lowest)"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "short_text0",
#                   "column": {
#                     "id": "short_text0",
#                     "title": "What would you need or expect from Tribe in the future to support you? (More actions, events, interactions, gatherings, guidance..?)"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "single_select6",
#                   "column": {
#                     "id": "single_select6",
#                     "title": "Are you continuing in Tribe Fellowship?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "short_text2",
#                   "column": {
#                     "id": "short_text2",
#                     "title": "What would you need or expect from Tribe in the future to support you? (More actions, events, interactions, gatherings, guidance..?)"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "multi_select9",
#                   "column": {
#                     "id": "multi_select9",
#                     "title": "In what ways have you been engaged in the community? You can choose multiple options."
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "short_text9",
#                   "column": {
#                     "id": "short_text9",
#                     "title": "Following some additional questions regarding basic information for us to understand the target group of Fellowship better:\n\nWhat nationality or nationalities do you hold?"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "single_select1",
#                   "column": {
#                     "id": "single_select1",
#                     "title": "How do you identify yourself?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "single_select9",
#                   "column": {
#                     "id": "single_select9",
#                     "title": "To what age range do you belong to?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "single_select4",
#                   "column": {
#                     "id": "single_select4",
#                     "title": "What is your current occupation?"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "true___false6",
#                   "column": {
#                     "id": "true___false6",
#                     "title": "Privacy policy\n\nWe need your consent to the storage and processing of your data in accordance with the privacy statement. \n\nCheck it out here: tribetampere.com/privacy-statement"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "short_text10",
#                   "column": {
#                     "id": "short_text10",
#                     "title": "Please spesify:"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "subitems",
#                   "column": {
#                     "id": "subitems",
#                     "title": "Subitems"
#                   },
#                   "text": null
#                 },
#                 {
#                   "id": "text",
#                   "column": {
#                     "id": "text",
#                     "title": "Impact/notes"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "short_text1",
#                   "column": {
#                     "id": "short_text1",
#                     "title": "Write down what other attributes would you like to get through the community circle."
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "short_text7",
#                   "column": {
#                     "id": "short_text7",
#                     "title": "Write here other skills you would like to develop."
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "true___false",
#                   "column": {
#                     "id": "true___false",
#                     "title": "Privacy policy"
#                   },
#                   "text": ""
#                 },
#                 {
#                   "id": "true___false3",
#                   "column": {
#                     "id": "true___false3",
#                     "title": "Do you live in Tampere area?"
#                   },
#                   "text": ""
#                 }
#               ]
#             }
#           ]
#         }
#       }
#     ]
#   }
# }

# %%
comreg_data = pd.DataFrame(rows)
comreg_data
# Out:
#              id                  name              Name  \
# 0    7415202559  Incoming form answer            Dmytro
# 1    7691210593  Incoming form answer       Deniz Turan
# 2    7693180568  Incoming form answer       Selene Gama
# 3    7703148193  Incoming form answer  Ifeoluwa Dosunmu
# 4    7831969992  Incoming form answer     Viola Tyynilä
# ..          ...                   ...               ...
# 108  7510267350  Incoming form answer
# 109  7684403762  Incoming form answer
# 110  7791577363              Shalinga
# 111  7800715006            Bora Altun
# 112  8436778916  Incoming form answer
#
#                        Status Date of Application Email Date  \
# 0    Did not show up/canceled          2024-09-12
# 1    Did not show up/canceled          2024-10-23
# 2    Did not show up/canceled          2024-10-23
# 3            reminded to book          2024-10-24
# 4            reminded to book          2024-11-12
# ..                        ...                 ...        ...
# 108         Onboarding booked          2024-09-26
# 109         Onboarding booked          2024-10-22
# 110         Onboarding booked          2024-11-06
# 111         Onboarding booked          2024-11-07
# 112         Onboarding booked          2025-02-09
#
#     Do you want to continue in Tribe Fellowship?                      email  \
# 0                                           None         Pradovd4@gmail.com
# 1                                           None    denizturan905@gmail.com
# 2                                           None    selenegama.br@gmail.com
# 3                                           None  ifeoluwajewel06@gmail.com
# 4                                           None     violatyynila@gmail.com
# ..                                           ...                        ...
# 108                                          Yes
# 109                                          Yes
# 110                                         None
# 111                                         None
# 112                                          Yes
#
#     Do you have a startup/business idea that you want to work on?  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 108                                               None
# 109                                               None
# 110                                               None
# 111                                               None
# 112                                               None
#
#     Describe the idea or a project that you are building on.  ...  \
# 0                                                             ...
# 1                                                             ...
# 2                                                             ...
# 3                                                             ...
# 4                                                             ...
# ..                                                 ...        ...
# 108                                                           ...
# 109                                                           ...
# 110                                                           ...
# 111                                                           ...
# 112                                                           ...
#
#     To what age range do you belong to? What is your current occupation?  \
# 0                                  None                             None
# 1                                  None                             None
# 2                                  None                             None
# 3                                  None                             None
# 4                                  None                             None
# ..                                  ...                              ...
# 108                                None                             None
# 109                                None                             None
# 110                               30-50                     Entrepreneur
# 111                               30-50                     Entrepreneur
# 112                                None                             None
#
#     Privacy policy\n\nWe need your consent to the storage and processing of your data in accordance with the privacy statement. \n\nCheck it out here: tribetampere.com/privacy-statement  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 108
# 109
# 110                                                  v
# 111                                                  v
# 112
#
#     Please spesify: Subitems Impact/notes  \
# 0                       None
# 1                       None
# 2                       None
# 3                       None
# 4                       None
# ..              ...      ...          ...
# 108                     None
# 109                     None
# 110                     None
# 111                     None
# 112                     None
#
#     Write down what other attributes would you like to get through the community circle.  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 108
# 109
# 110
# 111
# 112
#
#     Write here other skills you would like to develop. Privacy policy  \
# 0                                                                   v
# 1                                                                   v
# 2                                                                   v
# 3                                                                   v
# 4                                                                   v
# ..                                                 ...            ...
# 108
# 109
# 110                                                                 v
# 111                                                                 v
# 112
#
#     Do you live in Tampere area?
# 0                              v
# 1                              v
# 2                              v
# 3                              v
# 4                              v
# ..                           ...
# 108
# 109
# 110
# 111
# 112
#
# [113 rows x 53 columns]

# %%
#comreg_data.loc[comreg_data['Name'] == '']

# %%
comreg_data['Name'].duplicated().count()
# Out:
# np.int64(113)

# %%
comreg_data.describe()
# Out:
#                 id                  name Name     Status Date of Application  \
# count          113                   113  113        113                 113
# unique         113                     7  100          4                  88
# top     7415202559  Incoming form answer       Onboarded          2025-04-10
# freq             1                    99   12         63                   6
#
#        Email Date Do you want to continue in Tribe Fellowship? email  \
# count         113                                            6   113
# unique          7                                            1    99
# top                                                        Yes
# freq          105                                            6    13
#
#        Do you have a startup/business idea that you want to work on?  \
# count                                                  29
# unique                                                  2
# top           No, I would just like to join the community
# freq                                                   19
#
#        Describe the idea or a project that you are building on.  ...  \
# count                                                 113        ...
# unique                                                 11        ...
# top                                                              ...
# freq                                                  103        ...
#
#        To what age range do you belong to? What is your current occupation?  \
# count                                    6                                6
# unique                                   2                                3
# top                                  30-50                     Entrepreneur
# freq                                     5                                3
#
#        Privacy policy\n\nWe need your consent to the storage and processing of your data in accordance with the privacy statement. \n\nCheck it out here: tribetampere.com/privacy-statement  \
# count                                                 113
# unique                                                  2
# top
# freq                                                  106
#
#        Please spesify: Subitems Impact/notes  \
# count              113        0          113
# unique               2        0            1
# top                         NaN
# freq               112      NaN          113
#
#        Write down what other attributes would you like to get through the community circle.  \
# count                                                 113
# unique                                                  5
# top
# freq                                                  109
#
#        Write here other skills you would like to develop. Privacy policy  \
# count                                                 113            113
# unique                                                  8              2
# top                                                                    v
# freq                                                  106             98
#
#        Do you live in Tampere area?
# count                           113
# unique                            2
# top                               v
# freq                             91
#
# [4 rows x 53 columns]

# %%
comreg_data.columns
# Out:
# Index(['id', 'name', 'Name', 'Status', 'Date of Application', 'Email Date',
#        'Do you want to continue in Tribe Fellowship?', 'email',
#        'Do you have a startup/business idea that you want to work on?',
#        'Describe the idea or a project that you are building on.',
#        'Which stage/target group do you belong to?',
#        'What is your progress so far?',
#        'What are you next steps for your project?',
#        'What skills do you feel like you need to develop to take your project forward?',
#        'How do you want to be involved within the community?',
#        'What skills are you looking forward to developing by joining the Fellowship?',
#        'What attributes are you aiming to get through Fellowship?',
#        'Write an attribute you like to get through the fellowship',
#        'Write here other skills you would like to develop',
#        'What part of the community circle are you most interested in?',
#        'What skills are you looking forward to developing during your time in the Community Circle',
#        'What attributes are you aiming to get through the Community Circle?',
#        'Where or from whom did you hear about Fellowship?',
#        'Anything else you want to tell us? (achievements, expectations, goals, needs.....?)',
#        'Date of onboarding',
#        'What traits/skills have you been able to improve/develop during your time in Fellowship?',
#        'What have you accomplished during 6 months in Fellowship?',
#        'Highlight some experiences in the last 6 months (3 favorite moments/events/achievements/learnings…)',
#        'How likely would you recommend Tribe Fellowship (Startup Catalyst or Community Circle) to a friend on a scale of 1-10 (1 lowest, 10 highest)',
#        'How likely would you recommend the Tribe community to a friend on a scale of 1-10 (1 lowest, 10 highest)',
#        'Open feedback :)',
#        'Privacy policy\n\nWe need your consent to the storage and processing of your data in accordance with the privacy statement. \nCheck it out here: tribetampere.com/privacy-statement',
#        'What do you want to accomplish in the next 6 months in Fellowship?',
#        'Have you moved to another program/organization/position/other?',
#        'Where have you moved on to?', 'What are your future plans?',
#        'How likely would you recommend Tribe Fellowship (Startup Catalyst or Community Circle) to a friend on a scale of 1-10',
#        'How likely would you recommend the Tribe community to a friend on a scale of 1-10 (10 highest, 1 lowest)',
#        'What would you need or expect from Tribe in the future to support you? (More actions, events, interactions, gatherings, guidance..?)',
#        'Are you continuing in Tribe Fellowship?',
#        'In what ways have you been engaged in the community? You can choose multiple options.',
#        'Following some additional questions regarding basic information for us to understand the target group of Fellowship better:\n\nWhat nationality or nationalities do you hold?',
#        'How do you identify yourself?', 'To what age range do you belong to?',
#        'What is your current occupation?',
#        'Privacy policy\n\nWe need your consent to the storage and processing of your data in accordance with the privacy statement. \n\nCheck it out here: tribetampere.com/privacy-statement',
#        'Please spesify:', 'Subitems', 'Impact/notes',
#        'Write down what other attributes would you like to get through the community circle.',
#        'Write here other skills you would like to develop.', 'Privacy policy',
#        'Do you live in Tampere area?'],
#       dtype='object')

# %%
comreg_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113 entries, 0 to 112
# Data columns (total 53 columns):
#  #   Column                                                                                                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                                                                                                             --------------  -----
#  0   id                                                                                                                                                                                 113 non-null    object
#  1   name                                                                                                                                                                               113 non-null    object
#  2   Name                                                                                                                                                                               113 non-null    object
#  3   Status                                                                                                                                                                             113 non-null    object
#  4   Date of Application                                                                                                                                                                113 non-null    object
#  5   Email Date                                                                                                                                                                         113 non-null    object
#  6   Do you want to continue in Tribe Fellowship?                                                                                                                                       6 non-null      object
#  7   email                                                                                                                                                                              113 non-null    object
#  8   Do you have a startup/business idea that you want to work on?                                                                                                                      29 non-null     object
#  9   Describe the idea or a project that you are building on.                                                                                                                           113 non-null    object
#  10  Which stage/target group do you belong to?                                                                                                                                         10 non-null     object
#  11  What is your progress so far?                                                                                                                                                      10 non-null     object
#  12  What are you next steps for your project?                                                                                                                                          113 non-null    object
#  13  What skills do you feel like you need to develop to take your project forward?                                                                                                     113 non-null    object
#  14  How do you want to be involved within the community?                                                                                                                               19 non-null     object
#  15  What skills are you looking forward to developing by joining the Fellowship?                                                                                                       19 non-null     object
#  16  What attributes are you aiming to get through Fellowship?                                                                                                                          19 non-null     object
#  17  Write an attribute you like to get through the fellowship                                                                                                                          113 non-null    object
#  18  Write here other skills you would like to develop                                                                                                                                  113 non-null    object
#  19  What part of the community circle are you most interested in?                                                                                                                      70 non-null     object
#  20  What skills are you looking forward to developing during your time in the Community Circle                                                                                         70 non-null     object
#  21  What attributes are you aiming to get through the Community Circle?                                                                                                                69 non-null     object
#  22  Where or from whom did you hear about Fellowship?                                                                                                                                  113 non-null    object
#  23  Anything else you want to tell us? (achievements, expectations, goals, needs.....?)                                                                                                113 non-null    object
#  24  Date of onboarding                                                                                                                                                                 113 non-null    object
#  25  What traits/skills have you been able to improve/develop during your time in Fellowship?                                                                                           113 non-null    object
#  26  What have you accomplished during 6 months in Fellowship?                                                                                                                          113 non-null    object
#  27  Highlight some experiences in the last 6 months (3 favorite moments/events/achievements/learnings…)                                                                                113 non-null    object
#  28  How likely would you recommend Tribe Fellowship (Startup Catalyst or Community Circle) to a friend on a scale of 1-10 (1 lowest, 10 highest)                                       6 non-null      object
#  29  How likely would you recommend the Tribe community to a friend on a scale of 1-10 (1 lowest, 10 highest)                                                                           6 non-null      object
#  30  Open feedback :)                                                                                                                                                                   113 non-null    object
#  31  Privacy policy
#
# We need your consent to the storage and processing of your data in accordance with the privacy statement.
# Check it out here: tribetampere.com/privacy-statement   113 non-null    object
#  32  What do you want to accomplish in the next 6 months in Fellowship?                                                                                                                 113 non-null    object
#  33  Have you moved to another program/organization/position/other?                                                                                                                     0 non-null      object
#  34  Where have you moved on to?                                                                                                                                                        113 non-null    object
#  35  What are your future plans?                                                                                                                                                        113 non-null    object
#  36  How likely would you recommend Tribe Fellowship (Startup Catalyst or Community Circle) to a friend on a scale of 1-10                                                              7 non-null      object
#  37  How likely would you recommend the Tribe community to a friend on a scale of 1-10 (10 highest, 1 lowest)                                                                           7 non-null      object
#  38  What would you need or expect from Tribe in the future to support you? (More actions, events, interactions, gatherings, guidance..?)                                               113 non-null    object
#  39  Are you continuing in Tribe Fellowship?                                                                                                                                            7 non-null      object
#  40  In what ways have you been engaged in the community? You can choose multiple options.                                                                                              7 non-null      object
#  41  Following some additional questions regarding basic information for us to understand the target group of Fellowship better:
#
# What nationality or nationalities do you hold?        113 non-null    object
#  42  How do you identify yourself?                                                                                                                                                      7 non-null      object
#  43  To what age range do you belong to?                                                                                                                                                6 non-null      object
#  44  What is your current occupation?                                                                                                                                                   6 non-null      object
#  45  Privacy policy
#
# We need your consent to the storage and processing of your data in accordance with the privacy statement.
#
# Check it out here: tribetampere.com/privacy-statement  113 non-null    object
#  46  Please spesify:                                                                                                                                                                    113 non-null    object
#  47  Subitems                                                                                                                                                                           0 non-null      object
#  48  Impact/notes                                                                                                                                                                       113 non-null    object
#  49  Write down what other attributes would you like to get through the community circle.                                                                                               113 non-null    object
#  50  Write here other skills you would like to develop.                                                                                                                                 113 non-null    object
#  51  Privacy policy                                                                                                                                                                     113 non-null    object
#  52  Do you live in Tampere area?                                                                                                                                                       113 non-null    object
# dtypes: object(53)
# memory usage: 46.9+ KB
